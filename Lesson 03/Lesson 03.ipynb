# %%
#####

a=1


######

# %%
a
# Out:
# 1

# %%
b=[1,2,3]

# %%
type(b)
# Out:
# list

# %%
print(b)
# Out:
# [1, 2, 3]

# %%
b
# Out:
# [1, 2, 3]

# %%
type(print)
# Out:
# builtin_function_or_method

# %%
type(type)
# Out:
# type

# %%
1+2
# Out:
# 3

# %%
for i in range(4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
a
# Out:
# 1

# %%
b
# Out:
# [1, 2, 3]

# %%
list_with_age = []
#snakecase

# %%
listWithAge = []
#camelcase

# %%
1+1j
# Out:
# (1+1j)

# %%
a=1
a=a+1

# %%
a
# Out:
# 2

# %%
int(5.6)
# Out:
# 5

# %%
7//3
# Out:
# 2

# %%
a=7
b=3
c=a//b
r=a%b

# %%
a,b,c,r
# Out:
# (7, 3, 2, 1)

# %%
2**3
# Out:
# 8

# %%
pow(2,3)
# Out:
# 8

# %%
n=1
m=2

n,m
# Out:
# (1, 2)

# %%
k=n
n=m
m=k
n,m
# Out:
# (2, 1)

# %%
n=int(input())
n
# Out:
#  1
# 1

# %%
n,m=m,n
n,m
# Out:
# (2, 1)

# %%
a=123

# %%
first_d=a//100
first_d
# Out:
# 1

# %%
last_d=a%10
last_d
# Out:
# 3

# %%
second_d=a%100//10
second_d
# Out:
# 2

# %%
first_d+second_d+last_d
# Out:
# 6

# %%
A0=1000
A0
# Out:
# 1000

# %%
A1=A0*(1+10)**2
A1
# Out:
# 121000

# %%
letter='b'
letter
# Out:
# 'b'

# %%
ord(letter)
# Out:
# 98

# %%
True, False
# Out:
# (True, False)

# %%
a=True

# %%
1>2
# Out:
# False

# %%
1=='1'
# Out:
# False

# %%
'a' in 'hall'
# Out:
# True

# %%
sentence='What are u doing?'

print(type(sentence))
print(len(sentence))
# Out:
# <class 'str'>
# 17

# %%
sentence[0]
# Out:
# 'W'

# %%
sentence[-1]
# Out:
# '?'

# %%
sentence[len(sentence)-1]
# Out:
# '?'

# %%
# sentence[start:stop:step] - slice
#sentence[1:5:2]
a='main academy'
a[1:7:2]
# Out:
# 'ana'
