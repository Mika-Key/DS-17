# %%
s='abshjsd,'

# %%
s
# Out:
# 'abshjsd,'

# %%
len(s)
# Out:
# 8

# %%
s*3
# Out:
# 'abshjsd,abshjsd,abshjsd,'

# %%
s+s
# Out:
# 'abshjsd,abshjsd,'

# %%
s.capitalize()
# Out:
# 'Abshjsd,'

# %%
s.count('j')
# Out:
# 1

# %%
s.find()
s.rfind()
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 1 in <module>
# TypeError: find() takes at least 1 argument (0 given)

# %%
s.upper()
# Out:
# 'ABSHJSD,'

# %%
s.split('s')
# Out:
# ['ab', 'hj', 'd,']

# %%
new_list=[1,2,3,'Sasha', 'Olya','qwrty']

# %%
new_list[3]
# Out:
# 'Sasha'

# %%
new_list[3]=new_list[3].lower()
new_list
# Out:
# [1, 2, 3, 'sasha', 'Olya', 'qwrty']

# %%
new_list+new_list
# Out:
# [1, 2, 3, 'sasha', 'Olya', 'qwrty', 1, 2, 3, 'sasha', 'Olya', 'qwrty']

# %%
new_list[-1]
# Out:
# 'qwrty'

# %%
students=['Sasha','Olya','Ihor', 'Katya']
students
# Out:
# ['Sasha', 'Olya', 'Ihor', 'Katya']

# %%
students.append('Marina')
students
# Out:
# ['Sasha', 'Olya', 'Ihor', 'Katya', 'Marina']

# %%
python=['Nataliia','Vitalii']
students.append(python)
students
# Out:
# ['Sasha', 'Olya', 'Ihor', 'Katya', 'Marina', ['Nataliia', 'Vitalii']]

# %%
del students[-1]
students
# Out:
# ['Sasha', 'Olya', 'Ihor', 'Katya', 'Marina']

# %%
students.extend(python)
students
# Out:
# ['Sasha', 'Olya', 'Ihor', 'Katya', 'Marina', 'Nataliia', 'Vitalii']

# %%
students+python
# Out:
# ['Sasha',
#  'Olya',
#  'Ihor',
#  'Katya',
#  'Marina',
#  'Nataliia',
#  'Vitalii',
#  'Nataliia',
#  'Vitalii']

# %%
#students +=python
#students = students+python

# %%
students.count('Sasha')
# Out:
# 1

# %%
students.pop()
students
# Out:
# ['Sasha', 'Olya', 'Ihor', 'Katya', 'Marina', 'Nataliia']

# %%
students.reverse()
students
# Out:
# ['Nataliia', 'Marina', 'Katya', 'Ihor', 'Olya', 'Sasha']

# %%
list(reversed(students))
# Out:
# ['Sasha', 'Olya', 'Ihor', 'Katya', 'Marina', 'Nataliia']

# %%
students
# Out:
# ['Nataliia', 'Marina', 'Katya', 'Ihor', 'Olya', 'Sasha']

# %%
a=[3,1,10,-5]
a.sort()
a
# Out:
# [-5, 1, 3, 10]

# %%
a=[3,1,10,-5]
a.sort(reverse=True)
a
# Out:
# [10, 3, 1, -5]

# %%
sorted(a)
# Out:
# [-5, 1, 3, 10]

# %%
sorted(a,reverse=True)
# Out:
# [10, 3, 1, -5]

# %%
sorted(['1','a','zz','A'])
# Out:
# ['1', 'A', 'a', 'zz']

# %%
'a'>'A'
# Out:
# True

# %%
'Sasha' in students
# Out:
# True

# %%
students=tuple(students)
students
# Out:
# ('Nataliia', 'Marina', 'Katya', 'Ihor', 'Olya', 'Sasha')

# %%
students[0]='Taras'
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 1 in <module>
# TypeError: 'tuple' object does not support item assignment

# %%
dict_with_students = {
    'Sasha':0,
    'Olya':0,
    'Ihor':0
}

# %%
dict_with_students
# Out:
# {'Sasha': 0, 'Olya': 0, 'Ihor': 0}

# %%
len(dict_with_students)
# Out:
# 3

# %%
dict_with_students['Sasha']=3

# %%
dict_with_students
# Out:
# {'Sasha': 3, 'Olya': 0, 'Ihor': 0}

# %%
dict_with_students.keys()
# Out:
# dict_keys(['Sasha', 'Olya', 'Ihor'])

# %%
dict_with_students.values()
# Out:
# dict_values([3, 0, 0])

# %%
list(dict_with_students.values())
# Out:
# [3, 0, 0]

# %%
dict_with_students.items()
# Out:
# dict_items([('Sasha', 3), ('Olya', 0), ('Ihor', 0)])

# %%
list(dict_with_students.items())
# Out:
# [('Sasha', 3), ('Olya', 0), ('Ihor', 0)]

# %%
dict_with_students.get('Alex',0)
# Out:
# 0

# %%
python={'Sasha', 'Olya', 'Ihor','Ihor'}
ds={'Nataliia', 'Marina', 'Katya','Ihor'}

# %%
python
# Out:
# {'Ihor', 'Olya', 'Sasha'}

# %%
#union - об'єднання

python | ds
# Out:
# {'Ihor', 'Katya', 'Marina', 'Nataliia', 'Olya', 'Sasha'}

# %%
# & intersection - перетин

python&ds
# Out:
# {'Ihor'}

# %%
# difference

python - ds
# Out:
# {'Olya', 'Sasha'}

# %%
python.add('qer')
python
# Out:
# {'Ihor', 'Olya', 'Sasha', 'qer'}

# %%
#bla lavka
student_age = 15

if student_age<18:
    print('BLOCK')
else:
    print('SAVE')
# Out:
# BLOCK
